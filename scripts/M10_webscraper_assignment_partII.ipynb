# %% [markdown]
# # DAV 6100: M10 Webscraper Assignment

# %% [markdown]
# ## Step 2 and 3: Creating s3 Bucket
#
# S3 bucket was created in AWS with the title "dav6100-databse-update-bucket".

# %%
####
#Author: brandon chiazza
#version 1.0
#references: 
#https://www.programiz.com/python-programming/working-csv-files
#https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html#S3.Client.create_bucket
#https://realpython.com/python-boto3-aws-s3/
#CLI aws s3api create-bucket --bucket my-bucket-name --region us-west-2 --create-bucket-configuration LocationConstraint=us-west-2
#https://robertorocha.info/setting-up-a-selenium-web-scraper-on-aws-lambda-with-python/ 
##

###Load libraries
import awscli
import selenium
import boto3
import pandas as pd
import time

from selenium import webdriver

####SCRAPE THE WEBSITE######
###call the webdriver
browser = webdriver.Chrome("/Users/Puji/Documents/DAV 6100 - Information Architectures/M10 Assignment/chromedriver 2")

#enter the url path that needs to be accessed by webdriver
browser.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

#identify xpath of location to select element
inputElement = browser.find_element_by_xpath("/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[2]/td[2]/input[1]")
inputElement.send_keys('0')
inputElement1 = browser.find_element_by_xpath("/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[10]/td/input[1]").click()

#identify the table to scrape
table = browser.find_element_by_css_selector('table.Bordered')

print(table)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1986fd8826286b2f3836d8cc13905771", element="c4a8642c-2183-4655-a977-7bcbcb7b0956")>

# %% [markdown]
# ## Step 4: Test Output of s3 Bucket

# %%
#####CREATE DATE FRAME#####
#create empty dataframe
df =[]


for i in range(7):
    i = i+1
    table = browser.find_element_by_css_selector('table.Bordered')
    #loop through dataframe to export table
    for row in table.find_elements_by_css_selector('tr'):
        cols = df.append([cell.text for cell in row.find_elements_by_css_selector('td')])

    #click through all 7 pages
    p = browser.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/span[2]/a['+str(i)+']').click()


#update dataframe with header 
df = pd.DataFrame(df, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])
display(df) #let's have a look at the data before creating the CSV file and loading it into s3
# Out:
#                                      Organization Name  NY Reg #        EIN  \
# 0                                                 None      None       None
# 1                              100 CLUB OF BUFFALO INC  03-01-89  160957291
# 2    100 E. 182ND Street Housing Development Fund C...  43-46-29  133881096
# 3                               100 GROTON PARKWAY INC  15-51-96  222661001
# 4                           100 Lives Foundation, Inc.  45-60-79  364808338
# 5                        100 Mile Man Foundation, Inc.  20-23-17  200565515
# 6                                     100 WHO CARE INC  06-65-86  134068307
# 7               100 Women in Finance Association, Inc.  20-90-57  571174550
# 8                    1026 Foundation Corporation (The)  46-42-92  823378707
# 9    1035 BROADWAY HOUSING DEVELOPMENT FUND COMPANY...  05-75-26  133870736
# 10              103rd Precinct Community Council, Inc.  41-40-17  205484666
# 11                       105TH FLOOR HEROES FUND, INC.  21-26-78  020560593
# 57              NFP             NEW YORK    NY
# 58              NFP             CARTHAGE    NY
# 59              NFP     LONG ISLAND CITY    NY
# 60              NFP            HEMPSTEAD    NY
# 61              NFP             BROOKLYN    NY
# 62              NFP          GARDEN CITY    NY
# 63              NFP             NEW YORK    NY
# 64             None                 None  None
# 65              NFP           GREENVILLE    SC
# 66              NFP             NEW YORK    NY
# 67              NFP                GERRY    NY
# 68              NFP             NEW YORK    NY
# 69              NFP          FULTONVILLE    NY
# 70              NFP             BROOKLYN    NY
# 71              NFP          KEW GARDENS    NY
# 72              NFP             NEW YORK    NY
# 73              NFP                HOMER    NY
# 74              NFP                PROVO    UT
# 75              NFP                BRONX    NY
# 76              NFP              CHICAGO    IL
# 77              NFP                BRONX    NY
# 78              NFP             BROOKLYN    NY
# 79              NFP             WOODMERE    NY
# 80             None                 None  None
# 81              NFP             NEW YORK    NY
# 82              NFP             BROOKLYN    NY
# 83              NFP       QUEENS VILLAGE    NY
# 84              NFP             NEW YORK    NY
# 85              NFP       FT. MONTGOMERY    NY
# 86              NFP             ELMSFORD    NY
# 87              NFP            KNOXVILLE    TN
# 88              NFP             NEW YORK    NY
# 89              NFP             ELMHURST    NY
# 90              NFP             NEW YORK    NY
# 91              NFP              CHICAGO    IL
# 92              NFP             NEW YORK    NY
# 93              NFP             NEW YORK    NY
# 94              NFP            FREDERICK    MD
# 95              NFP     ENGLEWOOD CLIFFS    NJ
# 96             None                 None  None
# 97              NFP           GREENVILLE    SC
# 98              NFP             NEW YORK    NY
# 99              NFP                GERRY    NY
# 100             NFP             NEW YORK    NY
# 101             NFP          FULTONVILLE    NY
# 102             NFP             BROOKLYN    NY
# 103             NFP          KEW GARDENS    NY
# 104             NFP             NEW YORK    NY
# 105             NFP                HOMER    NY
# 106             NFP                PROVO    UT
# 107             NFP                BRONX    NY
# 108             NFP              CHICAGO    IL
# 109             NFP                BRONX    NY
# 110             NFP             BROOKLYN    NY
# 111             NFP             WOODMERE    NY

# %%
###LOAD THE FILE INTO S3####
# prepare csv file name   
pathname = 's3:/dav6100-database-update-bucket/'#specify location of s3:/{my-bucket}/
filename= 'charities_bureau_scrape_II' #name of your group
datetime = time.strftime("%Y%m%d%H%M%S") #timestamp
filenames3 = "%s%s%s.csv"%(pathname,filename,datetime) #name of the filepath and csv file

#load file into s3. Pandas actually leverages boto to connect to s3 and can push the file directly into an s3 bucket
df.to_csv(filenames3, header=True, line_terminator='\n') 

#print success message
print("Successfull uploaded file to location:"+str(filenames3))
# Out:
# Successfull uploaded file to location:s3:/dav6100-database-update-bucket/charities_bureau_scrape_II20210419215827.csv

# %% [markdown]
# ## Step 6: Checking the File in s3 Bucket

# %%
#calling the .csv file from the s3 bucket to check for the header line
client = boto3.client('s3')

resource = boto3.resource('s3') 
my_bucket = resource.Bucket('my-bucket')

# %%
bucket = "dav6100-database-update-bucket"
file_name = "charities_bureau_scrape_20210419201829.csv"

s3 = boto3.client('s3') 

obj = s3.get_object(Bucket= bucket, Key= file_name) 

initial_df = pd.read_csv(obj['Body'])

# %%
initial_df.head()
# Out:
#    Unnamed: 0                                  Organization Name  NY Reg #  \
# 0           0                                                NaN       NaN
# 1           1                                 "Studio 5404" Inc.  44-39-58
# 2           2                      "THEY ARE HAITIAN" FUND, INC.  20-63-46
# 3           3  (ASMA) American Syrian Multicultural Associati...  42-84-63
# 4           4                                  #HicksStrong Inc.  48-10-48
#
#            EIN Registrant Type          City State
# 0          NaN             NaN           NaN   NaN
# 1  463180470.0             NFP    MASSAPAQUA    NY
# 2  300170128.0             NFP        HUDSON    NY
# 3  273130182.0             NFP      BROOKLYN    NY
# 4  842612081.0             NFP  CLIFTON PARK    NY

# %% [markdown]
# ## Step 7: Testing the File Output

# %%
initial_df = pd.DataFrame(initial_df, columns = ["Organization Name", "NY Reg #", "EIN", 
                                                  "Registrant Type", "City", "State"])
display(initial_df)
# Out:
#                                     Organization Name  NY Reg #          EIN  \
# 0                                                 NaN       NaN          NaN
# 1                                  "Studio 5404" Inc.  44-39-58  463180470.0
# 2                       "THEY ARE HAITIAN" FUND, INC.  20-63-46  300170128.0
# 3   (ASMA) American Syrian Multicultural Associati...  42-84-63  273130182.0
# 4                                   #HicksStrong Inc.  48-10-48  842612081.0
# 5                                #WalkAway Foundation  47-15-80  832820906.0
# 6                                 04/11 10:17 PM test  47-13-95  206256427.0
# 7                                 1/20/21 Action Fund  46-99-13  832210730.0
# 8                             10/40 Connections, Inc.  45-70-15  621825230.0
# 9                              1000 Feet Project, Inc  45-00-14  473820859.0
# 10                          1000 Islands Hose Haulers  45-38-38  454570241.0
# 11                              1004 Foundation, Inc.  45-00-13  463110658.0
# 12  100 BLACK MEN OF LONG ISLAND DEVELOPMENT GROUP...  20-08-47  113617702.0
# 13                            100 BLACKS WHO CARE INC  06-42-84  311628801.0
# 14      100 BLACK WOMEN OF LONG ISLAND FOUNDATION INC  05-79-45  113101805.0
# 15                                   100Cameras, Inc.  43-16-19  264692506.0
#
#    Registrant Type              City State
# 0              NaN               NaN   NaN
# 1              NFP        MASSAPAQUA    NY
# 2              NFP            HUDSON    NY
# 3              NFP          BROOKLYN    NY
# 4              NFP      CLIFTON PARK    NY
# 5              NFP          CARLSBAD    CA
# 6              NFP            ALBANY    NY
# 7              NFP     SAN FRANCISCO    CA
# 8              NFP            HIXSON    TN
# 9              NFP          NEW YORK    NY
# 10             NFP          CARTHAGE    NY
# 11             NFP  LONG ISLAND CITY    NY
# 12             NFP         HEMPSTEAD    NY
# 13             NFP          BROOKLYN    NY
# 14             NFP       GARDEN CITY    NY
# 15             NFP          NEW YORK    NY
